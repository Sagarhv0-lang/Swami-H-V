# %%
def print_info(**a):
    for key, value in a.items():
        print(f"{key}:{value}")

n=int(input("enter how many details you want?"))
data={}
for i in range(n):
    key=input(f"enter the name{i+1}:")
    value=input(f"enter value for {key}:")
    data[key]=value

print("ypur enter details are:\n")
print_info(**data)
# Out:
# enter how many details you want? 3
# enter the name1: maggi
# enter value for maggi: 5
# enter the name2: magesh
# enter value for magesh: 6
# enter the name3: varun
# enter value for varun: 7
# ypur enter details are:
#
# maggi:5
# magesh:6
# varun:7

# %%
def is_prime(num):
    if num <2:return False
    for i in range(2,int(num**0.5)+1):
        if num%i==0:return
    return True

n=int(input("enter a number to check if its prime:"))
