# %%
n=int(input("enter  number :"))
fact = 1
for i in range(1,n + 1):
    fact*= i
    print("Factorial :", fact)
# Out:
# enter  number : 5
# Factorial : 1
# Factorial : 2
# Factorial : 6
# Factorial : 24
# Factorial : 120

# %%
S=input()
count = 0
vowels=['a','e','i','o','u']
for i in S:
    if i in vowels:
        count+=1
print(count)
# Out:
#  sagar
# 2
